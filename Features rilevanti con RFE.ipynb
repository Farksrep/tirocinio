# %%
from sklearn import datasets
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.svm import SVR
from sklearn.preprocessing import normalize
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFE

# %%
#carico il dataset
data = pd.read_csv(r'C:\Users\Utente\anaconda3\Lib\site-packages\pandas\io\data_covnet_score-imputed_missRF_increasing_1.txt')

#creo un array che mi serve per salvare le informazioni delle features di volta in volta.
parzial_features=list()


nit=15


#Seleziono tutte le colonne tranne la prima.
features = [f for f in data.columns if f not in ['LABEL']]
X = data[features].values
y = data['LABEL'].values.ravel()

#creo un array monodimensionale lungo quanto "altri" ma solo di 0. 
y_pred=y-y

#classificatore
estimator = SVR(kernel="linear")
selector = RFE(estimator, n_features_to_select=20, step=1)
#le tre variabili sotto sono create per capire a che punto è l'esecuzione del programma, in quanto molto lento.
a=0
b=100000
c=40000
#crea un oggetto pronto ad operare: quando gli arriva in input qualcosa lo divide in 10 pezzettini con la stessa proporzione
skf = StratifiedKFold(n_splits=10)

for niter in range(nit):
    for train_index, test_index in skf.split(X, y):
        c=c+1
        print(c)

        X_train, X_test = X[train_index,:], X[test_index,:]
        y_train, y_test = y[train_index], y[test_index]

        selector=selector.fit( X_train, y_train)

        b=b+1
        print(b)

        #salvo tutte le volte i risultati ottenuti in un array.
        indexes = np.where(selector.support_ == True)
        for x in np.nditer(indexes):
            parzial_features.append(features[x])

        a=a+1
        print(a)


    
    #clf = rbf_svm.fit(X_train, y_train)
    #y_pred[test_index] = clf.predict(X_test)
    
    
    #fine ciclo for
#selector.support_

print()
for i in features:
  c=parzial_features.count(i)
  print(i,'        ', c)
# Out:
# 40001
# 100001
# 1
# 40002
# 100002
# 2
# 40003
# 100003
# 3
# 40004
# 100004
# 4
# 40005
# 100005
# 5
# 40006
# 100006
# 6
# 40007
# 100007
# 7
# 40008
# 100008
# 8
# 40009
# 100009
# 9
# 40010
# 100010
# 10
# 40011
# 100011
# 11
# 40012
# 100012
# 12
# 40013
# 100013
# 13
# 40014
# 100014
# 14
# 40015
# 100015
# 15
# 40016
# 100016
# 16
# 40017
# 100017
# 17
# 40018
# 100018
# 18
# 40019
# 100019
# 19
# 40020
# 100020
# 20
# 40021
# 100021
# 21
# 40022
# 100022
# 22
# 40023
# 100023
# 23
# 40024
# 100024
# 24
# 40025
# 100025
# 25
# 40026
# 100026
# 26
# 40027
# 100027
# 27
# 40028
# 100028
# 28
# 40029
# 100029
# 29
# 40030
# 100030
# 30
# 40031
# 100031
# 31
# 40032
# 100032
# 32
# 40033
# 100033
# 33
# 40034
# 100034
# 34
# 40035
# 100035
# 35
# 40036
# 100036
# 36
# 40037
# 100037
# 37
# 40038
# 100038
# 38
# 40039
# 100039
# 39
# 40040
# 100040
# 40
# 40041
# 100041
# 41
# 40042
# 100042
# 42
# 40043
# 100043
# 43
# 40044
# 100044
# 44
# 40045
# 100045
# 45
# 40046
# 100046
# 46
# 40047
# 100047
# 47
# 40048
# 100048
# 48
# 40049
# 100049
# 49
# 40050
# 100050
# 50
# 40051
# 100051
# 51
# 40052
# 100052
# 52
# 40053
# 100053
# 53
# 40054
# 100054
# 54
# 40055
# 100055
# 55
# 40056
# 100056
# 56
# 40057
# 100057
# 57
# 40058
# 100058
# 58
# 40059
# 100059
# 59
# 40060
# 100060
# 60
# 40061
# 100061
# 61
# 40062
# 100062
# 62
# 40063
# 100063
# 63
# 40064
# 100064
# 64
# 40065
# 100065
# 65
# 40066
# 100066
# 66
# 40067
# 100067
# 67
# 40068
# 100068
# 68
# 40069
# 100069
# 69
# 40070
# 100070
# 70
# 40071
# 100071
# 71
# 40072
# 100072
# 72
# 40073
# 100073
# 73
# 40074
# 100074
# 74
# 40075
# 100075
# 75
# 40076
# 100076
# 76
# 40077
# 100077
# 77
# 40078
# 100078
# 78
# 40079
# 100079
# 79
# 40080
# 100080
# 80
# 40081
# 100081
# 81
# 40082
# 100082
# 82
# 40083
# 100083
# 83
# 40084
# 100084
# 84
# 40085
# 100085
# 85
# 40086
# 100086
# 86
# 40087
# 100087
# 87
# 40088
# 100088
# 88
# 40089
# 100089
# 89
# 40090
# 100090
# 90
# 40091
# 100091
# 91
# 40092
# 100092
# 92
# 40093
# 100093
# 93
# 40094
# 100094
# 94
# 40095
# 100095
# 95
# 40096
# 100096
# 96
# 40097
# 100097
# 97
# 40098
# 100098
# 98
# 40099
# 100099
# 99
# 40100
# 100100
# 100
# 40101
# 100101
# 101
# 40102
# 100102
# 102
# 40103
# 100103
# 103
# 40104
# 100104
# 104
# 40105
# 100105
# 105
# 40106
# 100106
# 106
# 40107
# 100107
# 107
# 40108
# 100108
# 108
# 40109
# 100109
# 109
# 40110
# 100110
# 110
# 40111
# 100111
# 111
# 40112
# 100112
# 112
# 40113
# 100113
# 113
# 40114
# 100114
# 114
# 40115
# 100115
# 115
# 40116
# 100116
# 116
# 40117
# 100117
# 117
# 40118
# 100118
# 118
# 40119
# 100119
# 119
# 40120
# 100120
# 120
# 40121
# 100121
# 121
# 40122
# 100122
# 122
# 40123
# 100123
# 123
# 40124
# 100124
# 124
# 40125
# 100125
# 125
# 40126
# 100126
# 126
# 40127
# 100127
# 127
# 40128
# 100128
# 128
# 40129
# 100129
# 129
# 40130
# 100130
# 130
# 40131
# 100131
# 131
# 40132
# 100132
# 132
# 40133
# 100133
# 133
# 40134
# 100134
# 134
# 40135
# 100135
# 135
# 40136
# 100136
# 136
# 40137
# 100137
# 137
# 40138
# 100138
# 138
# 40139
# 100139
# 139
# 40140
# 100140
# 140
# 40141
# 100141
# 141
# 40142
# 100142
# 142
# 40143
# 100143
# 143
# 40144
# 100144
# 144
# 40145
# 100145
# 145
# 40146
# 100146
# 146
# 40147
# 100147
# 147
# 40148
# 100148
# 148
# 40149
# 100149
# 149
# 40150
# 100150
# 150
#
# CAT.Fever          135
# CAT.Cough          120
# CAT.Dyspnea          75
# CAT.IR          60
# CAT.Myalgias          90
# CAT.Other          120
# CAT.Syncope          120
# CAT.Asthenia          120
# CAT.Vomiting.Nausea          75
# CAT.Diarrhea          135
# CAT.Headache          60
# CAT.Pharingeal.pain          135
# INT.No.Symptoms          120
# CAT.Pneumo.asthma          75
# CAT.Pneumo.BPCO          90
# CAT.Neoplasia.last.5.years          150
# CAT.Smoke          90
# CAT.Arterial.hypertension          75
# CAT.Cardiovascular.pathologies          150
# CAT.Diabetes          105
# CAT.Obesity          90
# CAT.Celebral.stroke          150
# INT.No.Comorbidities          90
# CAT.Sex          30
# INT.Age          0
# INT.Symptoms.No.days          0
# INT.usa.radio.score.MAX          75
# INT.radio.SCORE          30
# NUM.GEO.extent.score          45
# NUM.OPC.extent.score          90
# INT.PaO2.PF          0
# INT.SpO2.in.FA          150
# INT.ALT          0
# INT.Platelets          0
# NUM.White.blood.cells          0
# NUM.Red.blood.cells          120
# NUM.Lymphocyte          0
# NUM.perc.Lymphocyte          0
# NUM.CRP          0
# NUM.Haemoglobin          15
# NUM.Haematocrit          15
